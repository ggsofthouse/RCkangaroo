# %% [markdown]
# # 🦘 RCKangaroo - GPU ECDLP Solver Notebook
# Notebook pronto para compilar e rodar o RCKangaroo diretamente em instâncias de GPU (Google Colab, Lightning.ai, Kaggle, etc.).

# %% [markdown]
# ## 1️⃣ Clonar o Repositório e Compilar para a GPU

# %%
# !git clone https://github.com/ggsofthouse/RCkangaroo.git
# %cd RCkangaroo
# !nvcc -O3 -std=c++17 -o rckangaroo RCKangaroo.cpp GpuKang.cpp Ec.cpp utils.cpp CallCubin.cpp RCGpuCore.cu -lcuda -lcudart -lpthread
# !./rckangaroo -list

# %% [markdown]
# ## 2️⃣ Executar o RCKangaroo

# %%
# Exemplo: Puzzle #66
# !./rckangaroo -gpu 0 -dp 16 -range 66 -start 60000000000000000 -pubkey 02145d223c51a33f932612296f6e3c2992ea7105642ead300067d2b0900139b85c

# %%
# Exemplo: Puzzle #140 (139 bits)
# !./rckangaroo -gpu 0 -dp 18 -range 139 -start 80000000000000000000000000000000000000 -pubkey 031f6a332d3c5c4f2de2378c012f429cd109ba07d69690c6c701b6bb87860d6640
